# %%
from music21 import *
# %matplotlib inline

# %%
paths = corpus.search('bwv295')

# %%
paths[0]
# Out:
# <music21.metadata.bundles.MetadataEntry: bach_bwv295_mxl>

# %%
bwv295 = corpus.parse('bach/bwv295')
for thisNote in bwv295.recurse().notes:
  thisNote.addLyric(thisNote.pitch.german)
bwv295.show()

# %%
environment.get("musescoreDirectPNGPath")
# Out:
# PosixPath('/usr/bin/musescore')

# %%
paths[0]
# Out:
# PosixPath('/home/krzysztof/fastai/lib/python3.6/site-packages/music21/corpus/bach/bwv1.6.mxl')

# %%
work = corpus.parse(paths[0])

# %%
work
# Out:
# <music21.stream.Score 0x7f0930c9a748>

# %%
work.show()
